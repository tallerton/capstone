# %%
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle('edge_df.pkl')

# %%
G = nx.from_pandas_edgelist(df, source='sender_id', target='receiver_id', edge_attr=["advice_freq"],create_using=nx.DiGraph())

plt.figure(3,figsize=(12,12)) 
nx.draw_random(G,with_labels=True)
plt.show()
